# %% [markdown]
# # Visualize Image Embeddings
# Now that we've collected all of the image embeddings into one place, we can visualize them.  To do this we'll use various projection algorithms from scikit learn to convert them to a 2-dimensional space we can visualize them, and then use Bokeh to make nice interactive charts.
#
# You have to launch `python -m SimpleHTTPServer` in your image directory to get the tooltip images to work.

# %%
import projtools
reload(projtools)
# Out:
# <module 'projtools' from 'projtools.pyc'>

# %%
features_file = "/data/africa2017/features/features-rot256.json"
fd = projtools.FeatureDict()
fd.load_json(features_file)

# %%
fd.ftr_matrix
# Out:
# array([[ 0.53318638,  3.83277154,  0.57834119, ...,  0.35179466,
#          0.8214885 ,  0.73904681],
#        [ 1.64695299,  0.14653416,  0.4825823 , ...,  0.82326329,
#          0.76226175,  0.44928095],
#        [ 1.55584395,  0.08741904,  0.68297189, ...,  0.56759346,
#          1.13845491,  0.44440094],
#        ...,
#        [ 1.52112746,  1.50854087,  0.28895995, ...,  0.1872488 ,
#          2.30366659,  1.73646104],
#        [ 0.40040985,  1.57477045,  0.7571823 , ...,  1.38597167,
#          0.85937774,  1.23852122],
#        [ 1.83352375,  0.18250319,  0.        , ...,  1.52337563,
#          0.28621542,  4.90630102]])

# %%
fd.ftr_matrix.shape
# Out:
# (2609, 2048)

# %%
import sklearn
from sklearn.decomposition import PCA

# %%
# %%time
proj_algo = PCA(n_components=2)
pca_proj = proj_algo.fit_transform(fd.ftr_matrix)
# Out:
# CPU times: user 488 ms, sys: 61.4 ms, total: 549 ms
# Wall time: 331 ms

# %%
pca_proj.shape
# Out:
# (2609, 2)

# %%
import bokeh
from bokeh.io import output_notebook, show
output_notebook()
from bokeh.plotting import figure
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d2466503-417b-478b-aa95-e2e00a12d70a">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.models import HoverTool
from bokeh.plotting import ColumnDataSource

pca_datasource = ColumnDataSource(data={
        "x": pca_proj[:,0],
        "y": pca_proj[:,1],
        "imgname": fd.names,        
    })
tooltip_html = """
        <div>  <span style="font-size:8px">@imgname</span>
            <img src="http://localhost:8000/@imgname.jpg" height=128 width=128></img>
        </div>
    """
f = figure(tools=["pan,wheel_zoom,box_zoom,reset,tap",HoverTool(tooltips = tooltip_html)],
           plot_width=800, plot_height=600, title="PCA")
f.circle('x','y', source=pca_datasource, size=15, alpha=0.3)
show(f)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a652f5d3-cebf-47b3-9eb0-87008083db17"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a652f5d3-cebf-47b3-9eb0-87008083db17");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a652f5d3-cebf-47b3-9eb0-87008083db17");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a652f5d3-cebf-47b3-9eb0-87008083db17' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"51615bde-745c-4fad-a149-a313de38e498":{"roots":{"references":[{"attributes":{"formatter":{"id":"ed461386-4137-43e3-b2c1-e45d2563094c","type":"BasicTickFormatter"},"plot":{"id":"a8313fdf-560c-4f2f-859f-b5af3d2e9958","subtype":"Figure","type":"Plot"},"ticker":{"id":"b1bb42b8-d74a-456a-a632-1f6d60aab57b","type":"BasicTicker"}},"id":"634ae985-1e05-46aa-9944-b6e109644e04","type":"LinearAxis"},{"attributes":{},"id":"ed461386-4137-43e3-b2c1-e45d2563094c","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"86f767bb-941f-415d-b3fe-e7bbd2aa53c7","type":"DataRange1d"},{"attributes":{},"id":"c2db2856-e60a-4e19-8b02-fd5ccc89fb22","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":15},"x":{"field":"x"},"y":{"field":"y"}},"id":"e04f0af3-0a56-47be-a0b2-325583465274","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"a8313fdf-560c-4f2f-859f-b5af3d2e9958","subtype":"Figure","type":"Plot"},"ticker":{"id":"c2db2856-e60a-4e19-8b02-fd5ccc89fb22","type":"BasicTicker"}},"id":"c09abc47-74ce-4e09-8f76-909f9947b69d","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2d7d53a5-53fb-4494-834e-bb4e283b91de","type":"HoverTool"},{"id":"b76dfe9e-e034-431e-9020-be2c8023c73b","type":"PanTool"},{"id":"90907e22-428c-4f11-8cd2-9e30441ce0bf","type":"WheelZoomTool"},{"id":"558a5eb1-b6df-49a5-8a75-70a13a1fb24b","type":"BoxZoomTool"},{"id":"302a321e-9477-44d9-9c4b-a585427fe913","type":"ResetTool"},{"id":"7ea4db20-64b6-4e07-9660-137b4c3f0e5d","type":"TapTool"}]},"id":"fee297be-18ef-4c4c-8409-88228e60fb19","type":"Toolbar"},{"attributes":{},"id":"b8551a64-06ae-43b7-bc0d-67bdc1eb509f","type":"BasicTickFormatter"},{"attributes":{"callback":null,"plot":{"id":"a8313fdf-560c-4f2f-859f-b5af3d2e9958","subtype":"Figure","type":"Plot"},"tooltips":"\n        <div>  <span style=\"font-size:8px\">@imgname</span>\n            <img src=\"http://localhost:8000/@imgname.jpg\" height=128 width=128></img>\n        </div>\n    "},"id":"2d7d53a5-53fb-4494-834e-bb4e283b91de","type":"HoverTool"},{"attributes":{"below":[{"id":"634ae985-1e05-46aa-9944-b6e109644e04","type":"LinearAxis"}],"left":[{"id":"49b0cca5-e75a-48a6-8ac1-e5be2295a928","type":"LinearAxis"}],"plot_width":800,"renderers":[{"id":"634ae985-1e05-46aa-9944-b6e109644e04","type":"LinearAxis"},{"id":"704c5d61-5842-49db-8b94-95dbb0d1d528","type":"Grid"},{"id":"49b0cca5-e75a-48a6-8ac1-e5be2295a928","type":"LinearAxis"},{"id":"c09abc47-74ce-4e09-8f76-909f9947b69d","type":"Grid"},{"id":"1ee06c1d-7a22-4cec-bde4-6f3a62bc20da","type":"BoxAnnotation"},{"id":"643ef4d3-c659-4132-84c2-ee667c9ed207","type":"GlyphRenderer"}],"title":{"id":"ac13e4e4-bca7-42ee-91d4-c001e04f602c","type":"Title"},"tool_events":{"id":"5516ece1-1ef2-4ca0-9d57-7260899117e0","type":"ToolEvents"},"toolbar":{"id":"fee297be-18ef-4c4c-8409-88228e60fb19","type":"Toolbar"},"x_range":{"id":"86f767bb-941f-415d-b3fe-e7bbd2aa53c7","type":"DataRange1d"},"y_range":{"id":"031aab53-7555-41c8-85c8-a4bd67afb94c","type":"DataRange1d"}},"id":"a8313fdf-560c-4f2f-859f-b5af3d2e9958","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.3},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.3},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":15},"x":{"field":"x"},"y":{"field":"y"}},"id":"91215cd5-46c0-4034-b985-6bb9cb1c31de","type":"Circle"},{"attributes":{"plot":{"id":"a8313fdf-560c-4f2f-859f-b5af3d2e9958","subtype":"Figure","type":"Plot"}},"id":"90907e22-428c-4f11-8cd2-9e30441ce0bf","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"a8313fdf-560c-4f2f-859f-b5af3d2e9958","subtype":"Figure","type":"Plot"}},"id":"302a321e-9477-44d9-9c4b-a585427fe913","type":"ResetTool"},{"attributes":{"overlay":{"id":"1ee06c1d-7a22-4cec-bde4-6f3a62bc20da","type":"BoxAnnotation"},"plot":{"id":"a8313fdf-560c-4f2f-859f-b5af ...

# %%
# %%time
from sklearn.manifold import TSNE, SpectralEmbedding, MDS
#proj_algo = MDS()
#proj_algo = SpectralEmbedding()
proj_algo = TSNE(perplexity=50, random_state=1234)
tsne_proj = proj_algo.fit_transform(fd.ftr_matrix)
# Out:
# CPU times: user 47.1 s, sys: 3.46 s, total: 50.6 s
# Wall time: 51.6 s

# %%
tsne_datasource = ColumnDataSource(data={
        "x": tsne_proj[:,0],
        "y": tsne_proj[:,1],
        "imgname": fd.names,        
    })
f = figure(tools=["pan,wheel_zoom,box_zoom,reset,tap",HoverTool(tooltips = tooltip_html)],
           plot_width=800, plot_height=600, title="t-SNE")
f.circle('x','y', source=tsne_datasource, size=15, alpha=0.3)
show(f)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8f250fdf-9218-4b68-9dac-68677eb36ad8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8f250fdf-9218-4b68-9dac-68677eb36ad8");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8f250fdf-9218-4b68-9dac-68677eb36ad8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8f250fdf-9218-4b68-9dac-68677eb36ad8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"77545140-2a37-451c-bf06-0d327912308e":{"roots":{"references":[{"attributes":{},"id":"fd22b651-1568-475d-ba35-444f8d6dd9c8","type":"BasicTicker"},{"attributes":{"callback":null,"plot":{"id":"bab5b2c1-7940-43ac-a168-2ec68cb7af8b","subtype":"Figure","type":"Plot"},"tooltips":"\n        <div>  <span style=\"font-size:8px\">@imgname</span>\n            <img src=\"http://localhost:8000/@imgname.jpg\" height=128 width=128></img>\n        </div>\n    "},"id":"46ca2d34-ce9f-407a-90a8-2e6187b8a635","type":"HoverTool"},{"attributes":{"fill_alpha":{"value":0.3},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.3},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":15},"x":{"field":"x"},"y":{"field":"y"}},"id":"7289a302-32a6-455b-869f-810e79d5a00b","type":"Circle"},{"attributes":{"formatter":{"id":"20df6671-e251-4c33-af32-ce3c439b0cff","type":"BasicTickFormatter"},"plot":{"id":"bab5b2c1-7940-43ac-a168-2ec68cb7af8b","subtype":"Figure","type":"Plot"},"ticker":{"id":"fd22b651-1568-475d-ba35-444f8d6dd9c8","type":"BasicTicker"}},"id":"f791d672-24fe-4cf5-a749-4e486fdba8ea","type":"LinearAxis"},{"attributes":{"overlay":{"id":"3bd90adc-2896-4ca8-b2e0-f5fdd29c6a1c","type":"BoxAnnotation"},"plot":{"id":"bab5b2c1-7940-43ac-a168-2ec68cb7af8b","subtype":"Figure","type":"Plot"}},"id":"61037d3b-dad1-4761-a5a9-9613ed3f3ea3","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":"t-SNE"},"id":"bebbd02b-eaff-4372-806a-b255dfe84558","type":"Title"},{"attributes":{"data_source":{"id":"d924d514-caf5-4e1a-913d-65b487905d2a","type":"ColumnDataSource"},"glyph":{"id":"7289a302-32a6-455b-869f-810e79d5a00b","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"cd5addde-288b-409c-b1ed-7bfc73399227","type":"Circle"},"selection_glyph":null},"id":"a63d35a8-42d8-43ec-88b5-e807e2248aa9","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"bab5b2c1-7940-43ac-a168-2ec68cb7af8b","subtype":"Figure","type":"Plot"}},"id":"bef71578-e2ed-41b9-a9c8-f19b683a5b47","type":"ResetTool"},{"attributes":{"formatter":{"id":"65470e06-8e02-45af-9bdd-ce6a7774aed2","type":"BasicTickFormatter"},"plot":{"id":"bab5b2c1-7940-43ac-a168-2ec68cb7af8b","subtype":"Figure","type":"Plot"},"ticker":{"id":"52d747ec-a686-4ffe-a85d-dbd084db9555","type":"BasicTicker"}},"id":"695a25e2-f52e-40e2-8ad8-a223e7fe9643","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":15},"x":{"field":"x"},"y":{"field":"y"}},"id":"cd5addde-288b-409c-b1ed-7bfc73399227","type":"Circle"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"46ca2d34-ce9f-407a-90a8-2e6187b8a635","type":"HoverTool"},{"id":"c9d384f8-ba1a-4785-85d8-8081b7fd63a3","type":"PanTool"},{"id":"b04952cc-c6ae-4262-a350-c5dad42e888e","type":"WheelZoomTool"},{"id":"61037d3b-dad1-4761-a5a9-9613ed3f3ea3","type":"BoxZoomTool"},{"id":"bef71578-e2ed-41b9-a9c8-f19b683a5b47","type":"ResetTool"},{"id":"a4ab1238-4bc2-45ac-8ba5-df77c7638a04","type":"TapTool"}]},"id":"036321b8-3dcd-46a1-ac57-25ca68b2b868","type":"Toolbar"},{"attributes":{"plot":{"id":"bab5b2c1-7940-43ac-a168-2ec68cb7af8b","subtype":"Figure","type":"Plot"}},"id":"c9d384f8-ba1a-4785-85d8-8081b7fd63a3","type":"PanTool"},{"attributes":{"plot":{"id":"bab5b2c1-7940-43ac-a168-2ec68cb7af8b","subtype":"Figure","type":"Plot"}},"id":"b04952cc-c6ae-4262-a350-c5dad42e888e","type":"WheelZoomTool"},{"attributes":{},"id":"20df6671-e251-4c33-af32-ce3c439b0cff","type":"BasicTickFormatter"},{"attributes":{"callback":null,"plot":{"id":"bab5b2c1-7940-43ac-a168-2ec68cb7af8b","subtype":"Figure","type":"Plot"}},"id":"a4ab1238-4bc2-45ac-8ba5-df77c7638a04","type":"TapTool"},{"attributes":{"plot":{"id":"bab5b2c1-7940-43ac-a168-2ec68cb7af8b","subtype":"Figure","type":"Plot"},"ticker":{"id":"fd22b651-1568-475d-ba35-444f8d6dd9c8","type":"BasicTicker"}},"id":"d59fb0cd-fe76-4227-989e-5f ...
